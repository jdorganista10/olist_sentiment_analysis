# %%
import pandas as pd
import numpy as np
import nltk

from collections import Counter
from nltk import word_tokenize
from sklearn.feature_extraction.text import CountVectorizer

# %%
df_or = pd.read_csv('Data/brazilian-ecommerce/olist_order_reviews_clean_dataset.csv')

# %%
print(len(df_or))
df_or.tail()
# Out:
# 38092
#                               review_id                          order_id  \
# 38087  98fffa80dc9acbde7388bef1600f3b15  d398e9c82363c12527f71801bf0e6100
# 38088  df5fae90e85354241d5d64a8955b2b09  509b86c65fe4e2ad5b96408cfef9755e
# 38089  b3de70c89b1510c4cd3d0649fd302472  55d4004744368f5571d1f590031933e4
# 38090  be360f18f5df1e0541061c87021e6d93  f8bd3f2000c28c5342fedeb5e50f2e75
# 38091  efe49f1d6f951dd88b51e6ccd4cc548f  90531360ecb1eec2a1fbb265a0db0508
#
#       review_score review_comment_title  \
# 38087            4                  NaN
# 38088            5                  NaN
# 38089            5                  NaN
# 38090            1                  NaN
# 38091            1                  NaN
#
#                                   review_comment_message review_creation_date  \
# 38087  para este produto recebi de acordo com a compr...  2017-11-29 00:00:00
# 38088  Entregou dentro do prazo. O produto chegou em ...  2018-02-07 00:00:00
# 38089  Excelente mochila, entrega super rápida. Super...  2018-03-22 00:00:00
# 38090  Solicitei a compra de uma capa de retrovisor c...  2017-12-15 00:00:00
# 38091  meu produto chegou e ja tenho que devolver, po...  2017-07-03 00:00:00
#
#       review_answer_timestamp  review_sentiment  \
# 38087     2017-11-30 15:52:51               1.0
# 38088     2018-02-19 19:47:23               1.0
# 38089     2018-03-23 09:10:43               1.0
# 38090     2017-12-16 01:29:43               0.0
# 38091     2017-07-03 21:01:49               0.0
#
#                                 review_comment_message_1  \
# 38087  para este produto recebi de acordo com a compr...
# 38088  entregou dentro do prazo. o produto chegou em ...
# 38089  excelente mochila, entrega super rápida. super...
# 38090  solicitei a compra de uma capa de retrovisor c...
# 38091  meu produto chegou e ja tenho que devolver, po...
#
#                                 review_comment_message_2
# 38087  para este produto recebi de acordo com a compr...
# 38088  entregou dentro do prazo  o produto chegou em ...
# 38089  excelente mochila  entrega super r pida  super...
# 38090  solicitei a compra de uma capa de retrovisor c...
# 38091  meu produto chegou e ja tenho que devolver  po...

# %%
df_or[df_or.review_comment_message.isna()]
# Out:
#       review_id                                           order_id  \
# 10790       NaN  estou aguardando a resposta de quando v o entr...
# 21897       NaN  a  nica coisa   a fatura ser pago somente no b...
#
#       review_score review_comment_title review_comment_message  \
# 10790          NaN                  NaN                    NaN
# 21897          NaN                  NaN                    NaN
#
#       review_creation_date review_answer_timestamp  review_sentiment  \
# 10790                  NaN                     NaN               NaN
# 21897                  NaN                     NaN               NaN
#
#       review_comment_message_1 review_comment_message_2
# 10790                      NaN                      NaN
# 21897                      NaN                      NaN
